# %%
# !pip install textgenie
# Out:
# Collecting textgenie
#   Downloading https://files.pythonhosted.org/packages/d5/1d/b7b49082bcd720efd61c15e01af49f56029f6bc205e838a568190b3771d3/textgenie-0.1.1-py3-none-any.whl
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from textgenie) (1.9.0+cu102)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from textgenie) (2.2.4)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/ac/aa/1437691b0c7c83086ebb79ce2da16e00bef024f24fec2a5161c35476f499/sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 6.7MB/s
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/00/92/6153f4912b84ee1ab53ab45663d23e7cf3704161cb5ef18b0c07e207cef2/transformers-4.7.0-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 17.6MB/s
# Collecting pattern
#   Downloading https://files.pythonhosted.org/packages/1e/07/b0e61b6c818ed4b6145fe01d1c341223aa6cfbc3928538ad1f2b890924a3/Pattern-3.6.0.tar.gz (22.2MB)
#      |████████████████████████████████| 22.3MB 125kB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from textgenie) (4.41.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->textgenie) (3.7.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (7.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (1.19.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (57.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (2.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->textgenie) (1.0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->textgenie) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->textgenie) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 22.2MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->textgenie) (4.5.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 32.0MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers->textgenie) (3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers->textgenie) (20.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pattern->textgenie) (0.16.0)
# Collecting backports.csv
#   Downloading https://files.pythonhosted.org/packages/8e/26/a6bd68f13e0f38fbb643d6e497fc3462be83a0b6c4d43425c78bb51a7291/backports.csv-1.0.7-py2.py3-none-any.whl
# Collecting mysqlclient
#   Downloading https://files.pythonhosted.org/packages/3c/df/59cd2fa5e48d0804d213bdcb1acb4d08c403b61c7ff7ed4dd4a6a2deb3f7/mysqlclient-2.0.3.tar.gz (88kB)
#      |████████████████████████████████| 92kB 9.2MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from pattern->textgenie) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pattern->textgenie) (4.2.6)
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/c6/ff/05da9ace6fc454c8d164f8b6dc7a12fb98b627e3a470b9718ade2e898b01/feedparser-6.0.7-py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 9.4MB/s
# Collecting pdfminer.six
#   Downloading https://files.pythonhosted.org/packages/93/f3/4fec7dabe8802ebec46141345bf714cd1fc7d93cb74ddde917e4b6d97d88/pdfminer.six-20201018-py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 22.2MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pattern->textgenie) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from pattern->textgenie) (3.2.5)
# Collecting python-docx
#   Downloading https://files.pythonhosted.org/packages/8b/a0/52729ce4aa026f31b74cc877be1d11e4ddeaa361dc7aebec148171644b33/python-docx-0.8.11.tar.gz (5.6MB)
#      |████████████████████████████████| 5.6MB 31.7MB/s
# Collecting cherrypy
#   Downloading https://files.pythonhosted.org/packages/a8/f9/e11f893dcabe6bc222a1442bf5e14f0322a2d363c92910ed41947078a35a/CherryPy-18.6.0-py2.py3-none-any.whl (419kB)
#      |████████████████████████████████| 419kB 25.6MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy->textgenie) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy->textgenie) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy->textgenie) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy->textgenie) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->textgenie) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->textgenie) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->textgenie) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->textgenie) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers->textgenie) (2.4.7)
# Collecting sgmllib3k
#   Downloading https://files.pythonhosted.org/packages/9e/bd/3704a8c3e0942d711c1299ebf7b9091930adae6675d7c8f476a7ce48653c/sgmllib3k-1.0.0.tar.gz
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pdfminer.six->pattern->textgenie) (2.4.0)
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/b2/26/7af637e6a7e87258b963f1731c5982fb31cd507f0d90d91836e446955d02/cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 24.1MB/s
# Collecting zc.lockfile
#   Downloading https://files.pythonhosted.org/packages/6c/2a/268389776288f0f26c7272c70c36c96dcc0bdb88ab6216ea18e19df1fadd/zc.lockfile-2.0-py2.py3-none-any.whl
# Collecting portend>=2.1.1
#   Downloading https://files.pythonhosted.org/packages/b8/a1/fd29409cced540facdd29abb986d988cb1f22c8170d10022ea73af77fa55/portend-2.7.1-py3-none-any.whl
# Collecting jaraco.collections
#   Downloading https://files.pythonhosted.org/packages/d5/1a/a0d6861d2aca6df92643c755966c8a60e40353e4c5e7a5c2f4e5ed733817/jaraco.collections-3.3.0-py3-none-any.whl
# Collecting cheroot>=8.2.1
#   Downloading https://files.pythonhosted.org/packages/46/95/86fe6480af78fea7b0e7e1bf02e6acd4cb9e561ea200bd6d6e1398fe5426/cheroot-8.5.2-py2.py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 10.0MB/s
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern->textgenie) (8.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six->pattern->textgenie) (1.14.5)
# Collecting tempora>=1.8
#   Downloading https://files.pythonhosted.org/packages/58/6e/928b4726ee2762efea4a84e8f5e73fb46b396636a5ec260d6274a1de24d5/tempora-4.1.1-py3-none-any.whl
# Collecting jaraco.text
#   Downloading https://files.pythonhosted.org/packages/c1/74/2a3c4835c079df16db8a9c50263eebb0125849fee5b16de353a059b7545d/jaraco.text-3.5.0-py3-none-any.whl
# Collecting jaraco.classes
#   Downloading https://files.pythonhosted.org/packages/b8/74/bee5fc11594974746535117546404678fc7b899476e769c3c55bc0cfaa02/jaraco.classes-3.2.1-py3-none-any.whl
# Collecting jaraco.functools
#   Downloading https://files.pythonhosted.org/packages/b5/da/e51e7b58c8fe132990edd1e3ef25bcd9801eb7f91d0f642ac7f8d97e4a36/jaraco.functools-3.3.0-py3-none-any.whl
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six->pattern->textgenie) (2.20)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern->textgenie) (2018.9)
# Building wheels for collected packages: pattern, mysqlclient, python-docx, sgmllib3k
#   Building wheel for pattern (setup.py) ... done
#   Created wheel for pattern: filename=Pattern-3.6-cp37-none-any.whl size=22332722 sha256=8c8ab42612d92c04e60159dbcbf34dbbbe716339bdae49a6a8f772824201ca17
#   Stored in directory: /root/.cache/pip/wheels/dc/9a/0e/5fb1a603ed4e3aa8722a88e9cf4a82da7d1b63e3d2cc34bee5
#   Building wheel for mysqlclient (setup.py) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.0.3-cp37-cp37m-linux_x86_64.whl size=100104 sha256=f44932b9b40e1dd0348f7c864eb96d84d29b12289f9ebf823f42870d6b0b2db2
#   Stored in directory: /root/.cache/pip/wheels/75/ca/e8/ad4e7ce3df18bcd91c7d84dd28c7c08db491a2a2360efed363
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-cp37-none-any.whl size=184508 sha256=311681619210a55cfd49ead5afdf80e37d20181a8035f7ffe7de63198c1c24a2
#   Stored in directory: /root/.cache/pip/wheels/a6/90/f1/a7cb70b38633ae04e7fb963b1c70f63fd6fc01c075b8230adc
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-cp37-none-any.whl size=6067 sha256=56a71e790a108ce9f2e4438ec656ea91b8d66158e82114373d222579ba933bcd
#   Stored in directory: /root/.cache/pip/wheels/f1/80/5a/444ba08a550cdd241bd9baf8bae44be750efe370adb944506a
# Successfully built pattern mysqlclient python-docx sgmllib3k
# Installing collected packages: sentencepiece, sacremoses, huggingface-hub, tokenizers, transformers, backports.csv, mysqlclient, sgmllib3k, feedparser, cryptography, pdfminer.six, python-docx, zc.lockfile, jaraco.functools, tempora, portend, jaraco.text, jaraco.classes, jaraco.collections, cheroot, cherrypy, pattern, textgenie
# Successfully installed backports.csv-1.0.7 cheroot-8.5.2 cherrypy-18.6.0 cryptography-3.4.7 feedparser-6.0.7 huggingface-hub-0.0.8 jaraco.classes-3.2.1 jaraco.collections-3.3.0 jaraco.functools-3.3.0 jaraco.text-3.5.0 mysqlclient-2.0.3 pattern-3.6 pdfminer.six-20201018 portend-2.7.1 python-docx-0.8.11 sacremoses-0.0.45 sentencepiece-0.1.96 sgmllib3k-1.0.0 tempora-4.1.1 textgenie-0.1.1 tokenizers-0.10.3 transformers-4.7.0 zc.lockfile-2.0

# %%
from textgenie import TextGenie

# %%
textgenie = TextGenie("ramsrigouthamg/t5_paraphraser",'bert-base-uncased')
# Out:
# Loading Paraphrase Model..
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1208.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691413.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1786.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=25.0, style=ProgressStyle(description_w…
# Loading Mask Fill Model..
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=570.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…

# %%
# Augment a list of sentences
sentences = ["The video was posted on Facebook by Alex.","I plan to run it again this time"]
textgenie.magic_lamp(sentences,"paraphrase: ",n_paraphrase_predictions=15,n_mask_predictions=15,convert_to_active=True)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:191: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# 100%|██████████| 2/2 [00:17<00:00,  8.76s/it]
# Completed writing output to /content/sentences_aug.txt.
# ['the clip was posted on facebook by alex.',
#  'the video was posted on vine by alex.',
#  'the video was posted on facebook by others.',
#  'the text was posted on facebook by alex.',
#  'the song was posted on facebook by alex.',
#  'the video was posted on facebook by friends.',
#  'the article was posted on facebook by alex.',
#  'the photo was posted on facebook by alex.',
#  'the video was posted on amazon by alex.',
#  'the video was posted on facebook by twitter.',
#  'the video was posted on facebook by rihanna.',
#  'the film was posted on facebook by alex.',
#  'the video was posted on twitch by alex.',
#  'the announcement was posted on facebook by alex.',
#  'the video was posted on blogs by alex.',
#  'the video was posted on video by alex.',
#  'the video was posted on facebook by her.',
#  'I just saw the video posted on Facebook by Alex Wenzel. This will impact to tell you more than we realise.',
#  'the video was posted on facebook by mtv.',
#  'the video was posted on myspace by alex.',
#  'the video was posted on twitter by alex.',
#  'the single was posted on facebook by alex.',
#  'the video was posted on itunes by alex.',
#  'What videos have you seen on FaceBook (Alex)?',
#  'the video was posted on site by alex.',
#  'the story was posted on facebook by alex.',
#  'the album was posted on facebook by alex.',
#  'The video was posted on Facebook by Alex Pease.',
#  'the cover was posted on facebook by alex.',
#  'the video was posted on tv by alex.',
#  'Alex posted the video on Facebook. ',
#  'If I could capture this on Facebook, what would be the point of posting an Instagram video?',
#  'the video was posted on internet by alex.',
#  'the video was posted on facebook by fans.',
#  'the video was posted on facebook by them.',
#  'the video was posted on google by alex.',
#  'the event was posted on facebook by alex.',
#  'This is a viral video I uploaded to Facebook and showed on my Facebook profile.',
#  'the video was posted on facebook by youtube.',
#  "This video was posted on Facebook by Alex. I've been using a mobile app for the past few days but just cant seem to find the time to download it.",
#  'the video was posted on facebook by himself.',
#  'the video was posted on mtv by alex.',
#  'the video was posted on facebook by him.',
#  'the trailer was posted on facebook by alex.',
#  'the video was posted on facebook by rt.',
#  'Is it true that the video, posted in Facebook, was created by Alex?',
#  "Watch Alex Rodriguez' Facebook video here.",
#  'the track was posted on facebook by alex.',
#  'the video was posted on facebook by fox.',
#  'The video was posted on Facebook by Alex.',
#  'the video was posted on facebook by anonymous.',
#  'the video was posted on facebook by members.',
#  'the video was posted on youtube by alex.',
#  'Is it possible to run it again after it starts if you want it again?',
#  'I plan to run It again this time now this time in Linux.',
#  'i plan to run it again this month',
#  'I plan to run it again this time this time.',
#  'i plan to run it again this weekend',
#  'How is this book going to be run again?',
#  'I plan to run it again this time this time this time.',
#  'i plan to run it again this!',
#  'I plan to run it again this time this time. It actually helps me. So, I will run it again.',
#  "I plan to run it again this time this time this time. I'm sure that I'll be able to find a runner again.",
#  'i plan to run it again this semester',
#  'i plan to run it again this week',
#  "I'll run it now again but the second time I've completed.",
#  'i plan to run it again this morning',
#  'i plan to run it again this season',
#  'i plan to run it again this.',
#  'I plan to run it again this time',
#  'i plan to run it again this year',
#  'i plan to run it again this?',
#  'i plan to run it again this...',
#  'i plan to run it again this ;',
#  "I plan to run this again this time this time around. I'll be writing more frequently than I have the time and the plan is much less complex.",
#  'I can always run it again, I just want to try putting it back. This time a fortnight after.',
#  "I plan to run it again this time I'm not going to run it again this time. If I didn't run it, I don't expect to miss out on it.",
#  'I will run it again. I plan to run it again this time.',
#  'i plan to run it again this summer',
#  'i plan to run it again this day',
#  "I plan to run it again this time this time again this time I can't remember whether I really needed to keep it running but its good enough.",
#  'I plan to run it again this time this time this time I know the plot. I guess they will be able to continue to run it then.',
#  'What is the plan to run it again?']

# %%
# %%writefile sentences.txt
# At dinner, six shrimp were eaten by Harry.
# Beautiful giraffes roam the savannah.
# Out:
# Writing sentences.txt

# %%
# Augment data in a txt file
textgenie.magic_lamp("sentences.txt","paraphrase: ",n_mask_predictions=5,convert_to_active=True)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:191: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
# Completed writing output to /content/sentences_aug.txt.
# ['at first, six shrimp were eaten by harry.',
#  'at dinner, six shrimp were eaten by hand.',
#  'at dinner, six dishes were eaten by harry.',
#  'at dinner, her shrimp were eaten by harry.',
#  'Harry ate six shrimp at dinner. ',
#  'at least, six shrimp were eaten by harry.',
#  'at dinner, six shrimp were eaten by him.',
#  'at dinner, six eggs were eaten by harry.',
#  'at dinner, six shrimp were eaten by themselves.',
#  'At dinner, Harry ate six shrimp.',
#  'At dinner, Harry was having 6 shrimps.',
#  'At dinner, six shrimp were eaten by Harry.',
#  'at dinner, the shrimp were eaten by harry.',
#  'at dinner, these shrimp were eaten by harry.',
#  'Harry ate six shrimp.',
#  "During Harry's dinner, he ate eight shrimp.",
#  'at dinner, his shrimp were eaten by harry.',
#  'at dinner, six shrimp were eaten by chicken.',
#  'at dinner, six meals were eaten by harry.',
#  "During Harry's dinner, six shrimp were eaten by Harry.",
#  'at night, six shrimp were eaten by harry.',
#  'at lunch, six shrimp were eaten by harry.',
#  'at dinner, six pancakes were eaten by harry.',
#  'at dinner, six sandwiches were eaten by harry.',
#  'at dinner, some shrimp were eaten by harry.',
#  'at dinner, six shrimp were eaten by everyone.',
#  'Beautiful giraffes roam the savannah.',
#  'beautiful giraffes roam the streets.',
#  'beautiful women roam the savannah.',
#  'little giraffes roam the savannah.',
#  'beautiful butterflies roam the savannah.',
#  'wild giraffes roam the savannah.',
#  'How many beautiful giraffes do you see in the savannah?',
#  'beautiful giraffes roam the park.',
#  'large giraffes roam the savannah.',
#  'beautiful birds roam the savannah.',
#  'What are some impressive giraffes that roam the Savannah?',
#  'beautiful animals roam the savannah.',
#  'beautiful giraffes roam the land.',
#  'the giraffes roam the savannah.',
#  'beautiful giraffes roam the grounds.',
#  'Beautiful giraffes roam the Savanna.',
#  'beautiful creatures roam the savannah.',
#  'In winter, in the middle of nowhere, a giraffe roams the Sabana Desert. What do they do?',
#  'black giraffes roam the savannah.',
#  'beautiful giraffes roam the beach.']

# %%
# %%writefile dataset.csv
# Sue changed the flat tire., Label1
# The crew paved the entire stretch of highway.,Label1
# The critic wrote a scathing review.,Label2
# I will clean the house every Saturday.,Label2
# Out:
# Overwriting dataset.csv

# %%
# Augment data in a csv file with labels
augmented_dataset = textgenie.magic_lamp("dataset.csv","paraphrase: ",n_paraphrase_predictions=15,n_mask_predictions=15,convert_to_active=True,column_names=["Text","Label"])
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:191: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# 100%|██████████| 3/3 [00:22<00:00,  7.53s/it]
# Completed writing output to /content/dataset_aug.csv.

# %%
augmented_dataset
# Out:
#                                                   Text    Label
# 0        the crew paved the entire section of highway.   Label1
# 1           the crew paved the entire stretch of road.   Label1
# 2         the crew paved the short stretch of highway.   Label1
# 3    How did a US crew paved the entire stretch of ...   Label1
# 4          the crew paved the entire route of highway.   Label1
# ..                                                 ...      ...
# 165                 i will clean the house every week.  Label2
# 166          i will clean the basement every saturday.  Label2
# 167              i will clean the house every weekend.  Label2
# 168              i will clean the yard every saturday.  Label2
# 169                  i will clean the house every day.  Label2
#
# [170 rows x 2 columns]
